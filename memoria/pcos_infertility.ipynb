# %%
import pandas as pd
import numpy as np

# %%
pcos_inf = pd.read_excel("../data/PCOS_data_without_infertility.xlsx")
pcos_inf
# Out:
#     Instructions to be followed :  \
# 0                             NaN
# 1                             1.0
# 2                             2.0
# 3                             3.0
# 4                             4.0
# 5                             5.0
# 6                             NaN
# 7                             NaN
# 8                             NaN
# 9                             NaN
# 10                            NaN
# 11                            NaN
# 12                            NaN
# 13                            6.0
# 14                            7.0
# 15                            8.0
# 16                            9.0
# 17                           10.0
# 18                           11.0
# 19                           12.0
#
#                                            Unnamed: 1  Unnamed: 2 Unnamed: 3
# 0                                                 NaN         NaN        NaN
# 1    Kindly ensure that the datas are converted to...         NaN        NaN
# ...

# %%
pcos = pd.read_csv("../data/PCOS_infertility.csv")
pcos
# Out:
#      Sl. No  Patient File No.  PCOS (Y/N)    I   beta-HCG(mIU/mL)  \
# 0         1             10001           0                    1.99
# 1         2             10002           0                   60.80
# 2         3             10003           1                  494.08
# 3         4             10004           0                    1.99
# 4         5             10005           0                  801.45
# ..      ...               ...         ...                     ...
# 536     537             10537           0                    1.99
# 537     538             10538           0                   80.13
# 538     539             10539           0                    1.99
# 539     540             10540           0                  292.92
# 540     541             10541           1                    1.99
#
#      II    beta-HCG(mIU/mL) AMH(ng/mL)
# 0                      1.99       2.07
# 1                      1.99       1.53
# 2                    494.08       6.63
# ...
